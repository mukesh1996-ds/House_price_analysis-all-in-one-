# %% [markdown]
# In this notebook I am going to analysis all the inspect of the dataset.
#
# I am applying the following:
#
# * information
# * describe
# * null value
# * cleaning the dataset

# %%
# Loading the packages 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cufflinks as cf
import plotly.offline
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Loading the dataset 

df = pd.read_csv(r'D:\Final submission\EDA\House_price_analysis-all-in-one-\dataset\train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# Data fields
# Here's a brief version of what you'll find in the data description file.
#
# 0. id : unique name
# 1. SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# 2. MSSubClass: The building class
# 3. MSZoning: The general zoning classification
# 4. LotFrontage: Linear feet of street connected to property
# 5. LotArea: Lot size in square feet
# 6. Street: Type of road access
# 7. Alley: Type of alley access
# 8. LotShape: General shape of property
# 9. LandContour: Flatness of the property
# 10. Utilities: Type of utilities available
# 11. LotConfig: Lot configuration
# 12. LandSlope: Slope of property
# 13. Neighborhood: Physical locations within Ames city limits
# 14. Condition1: Proximity to main road or railroad
# 15. Condition2: Proximity to main road or railroad (if a second is present)
# 16. BldgType: Type of dwelling
# 17. HouseStyle: Style of dwelling
# 18. OverallQual: Overall material and finish quality
# 19. OverallCond: Overall condition rating
# 20. YearBuilt: Original construction date
# 21. YearRemodAdd: Remodel date
# 22. RoofStyle: Type of roof
# 23. RoofMatl: Roof material
# 24. Exterior1st: Exterior covering on house
# 25. Exterior2nd: Exterior covering on house (if more than one material)
# 26. MasVnrType: Masonry veneer type
# 27. MasVnrArea: Masonry veneer area in square feet
# 28. ExterQual: Exterior material quality
# 29. ExterCond: Present condition of the material on the exterior
# 30. Foundation: Type of foundation
# 31. BsmtQual: Height of the basement
# 32. BsmtCond: General condition of the basement
# 33. BsmtExposure: Walkout or garden level basement walls
# 34. BsmtFinType1: Quality of basement finished area
# 35. BsmtFinSF1: Type 1 finished square feet
# 36. BsmtFinType2: Quality of second finished area (if present)
# 37. BsmtFinSF2: Type 2 finished square feet
# 38. BsmtUnfSF: Unfinished square feet of basement area
# 39. TotalBsmtSF: Total square feet of basement area
# 40. Heating: Type of heating
# 41. HeatingQC: Heating quality and condition
# 42. CentralAir: Central air conditioning
# 43. Electrical: Electrical system
# 44. 1stFlrSF: First Floor square feet
# 45. 2ndFlrSF: Second floor square feet
# 46. LowQualFinSF: Low quality finished square feet (all floors)
# 47. GrLivArea: Above grade (ground) living area square feet
# 48. BsmtFullBath: Basement full bathrooms
# 49. BsmtHalfBath: Basement half bathrooms
# 50. FullBath: Full bathrooms above grade
# 51. HalfBath: Half baths above grade
# 52. Bedroom: Number of bedrooms above basement level
# 53. Kitchen: Number of kitchens
# 54. KitchenQual: Kitchen quality
# 55. TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# 56. Functional: Home functionality rating
# 57. Fireplaces: Number of fireplaces
# 58. FireplaceQu: Fireplace quality
# 59. GarageType: Garage location
# 60. GarageYrBlt: Year garage was built
# 61. GarageFinish: Interior finish of the garage
# 62. GarageCars: Size of garage in car capacity
# 63. GarageArea: Size of garage in square feet
# 64. GarageQual: Garage quality
# 65. GarageCond: Garage condition
# 66. PavedDrive: Paved driveway
# 67. WoodDeckSF: Wood deck area in square feet
# 68. OpenPorchSF: Open porch area in square feet
# 69. EnclosedPorch: Enclosed porch area in square feet
# 70. 3SsnPorch: Three season porch area in square feet
# 71. ScreenPorch: Screen porch area in square feet
# 72. PoolArea: Pool area in square feet
# 73. PoolQC: Pool quality
# 74. Fence: Fence quality
# 75. MiscFeature: Miscellaneous feature not covered in other categories
# 76. MiscVal: $Value of miscellaneous feature
# 77. MoSold: Month Sold
# 78. YrSold: Year Sold
# 79. SaleType: Type of sale
# 80. SaleCondition: Condition of sale

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [markdown]
# From the above we can see that there are the following:
# * object dtype ---> 43
# * int dtype --> 35
# * float dtype --> 3

# %%
# check the null values:

df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %% [markdown]
# from the above we can see that there are multiple columns who have missing values so our first task is to clean the values and make the data ready.

# %%
# let's calculate the percentage of missing values in my dataset.
percentage_missing_value = df.isnull().sum()/len(df) * 100.

# %%
percentage_missing_value.round(2)
# Out:
# Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# Street            0.00
# Alley            93.77
# LotShape          0.00
# LandContour       0.00
# Utilities         0.00
# LotConfig         0.00
# LandSlope         0.00
# Neighborhood      0.00
# Condition1        0.00
# Condition2        0.00
# BldgType          0.00
# HouseStyle        0.00
# OverallQual       0.00
# OverallCond       0.00
# YearBuilt         0.00
# YearRemodAdd      0.00
# RoofStyle         0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# MasVnrType        0.55
# MasVnrArea        0.55
# ExterQual         0.00
# ExterCond         0.00
# Foundation        0.00
# BsmtQual          2.53
# BsmtCond          2.53
# BsmtExposure      2.60
# BsmtFinType1      2.53
# BsmtFinSF1        0.00
# BsmtFinType2      2.60
# BsmtFinSF2        0.00
# BsmtUnfSF         0.00
# TotalBsmtSF       0.00
# Heating           0.00
# ...

# %% [markdown]
# Let's print all the percentage of missing values in my dataset.

# %%
print('The percentage of missing value are \n {} '.format(percentage_missing_value.round(2)))
# Out:
# The percentage of missing value are
#  Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# Street            0.00
# Alley            93.77
# LotShape          0.00
# LandContour       0.00
# Utilities         0.00
# LotConfig         0.00
# LandSlope         0.00
# Neighborhood      0.00
# Condition1        0.00
# Condition2        0.00
# BldgType          0.00
# HouseStyle        0.00
# OverallQual       0.00
# OverallCond       0.00
# YearBuilt         0.00
# YearRemodAdd      0.00
# RoofStyle         0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# MasVnrType        0.55
# MasVnrArea        0.55
# ExterQual         0.00
# ExterCond         0.00
# Foundation        0.00
# BsmtQual          2.53
# BsmtCond          2.53
# BsmtExposure      2.60
# BsmtFinType1      2.53
# BsmtFinSF1        0.00
# BsmtFinType2      2.60
# BsmtFinSF2        0.00
# BsmtUnfSF         0.00
# ...

# %% [markdown]
# let's print all the column name that have missing value more than 17%

# %%
missing_data_values = percentage_missing_value[percentage_missing_value>17].keys()
missing_data_values
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %% [markdown]
# now we can directly remove the columns

# %%
df.drop(columns=['Id','LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence','MiscFeature'],
        axis=1, 
        inplace=True)

# %% [markdown]
# Let's check the output

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %% [markdown]
# recheck the missing values

# %%
df.isnull().sum()
# Out:
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
# BsmtExposure     38
# BsmtFinType1     37
# BsmtFinSF1        0
# BsmtFinType2     38
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        1
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# ...

# %% [markdown]
# now let's print only the missing values

# %%
percentage_missing_value = df.isnull().sum()/len(df) * 100
missing_value = percentage_missing_value[percentage_missing_value>1].keys()

# %%
missing_value
# Out:
# Index(['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual',
#        'GarageCond'],
#       dtype='object')

# %% [markdown]
# let's handle all the missing values

# %%
df['BsmtQual'] = df['BsmtQual'].fillna(df['BsmtQual'].mode)

# %%
df['BsmtCond'] = df['BsmtCond'].fillna(df['BsmtCond'].mode)

# %%
df['BsmtExposure'] = df['BsmtExposure'].fillna(df['BsmtExposure'].mode)

# %%
df['BsmtFinType1'] = df['BsmtFinType1'].fillna(df['BsmtFinType1'].mode)

# %%
df['BsmtFinType2'] = df['BsmtFinType2'].fillna(df['BsmtFinType2'].mode)

# %%
df['GarageType'] = df['GarageType'].fillna(df['GarageType'].mode)

# %%
sns.displot(df['GarageYrBlt'])

# %%
df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].median)

# %%
df['GarageFinish'] = df['GarageFinish'].fillna(df['GarageFinish'].mode)

# %%
df['GarageQual'] = df['GarageQual'].fillna(df['GarageQual'].mode)

# %%
df['GarageCond'] = df['GarageCond'].fillna(df['GarageCond'].mode)

# %% [markdown]
# we have updated all the values and let's recheck all the missing values again

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       8
# MasVnrArea       8
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       1
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# ...

# %%
#  even now there are missing values let's drop all of them
df.dropna(inplace=True)

# %%
# let's create heatmap to check the missing values

sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above we can see that there are no missing values persent inside my data and everything look good now
# let's check the head of data.

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
#    OverallQual  OverallCond  YearBuilt  YearRemodAdd RoofStyle RoofMatl  \
# ...

# %%
df.drop(columns=['LandContour', 'LotConfig',	'LandSlope', 'Condition2', 'HouseStyle', 'OverallQual', 'YearRemodAdd', 'RoofMatl','Exterior1st', 'MasVnrType', 'MasVnrArea', 'ExterQual',	'ExterCond', 'BsmtQual','BsmtCond',	'BsmtExposure',	'BsmtFinType1',	'BsmtFinSF1',	'BsmtFinType2',	'BsmtFinSF2',	'BsmtUnfSF', 'HeatingQC', '2ndFlrSF', 'LowQualFinSF',	'GrLivArea',	'BsmtFullBath',	'BsmtHalfBath',	'FullBath',	'HalfBath','KitchenQual', 'Functional','Fireplaces', 'GarageYrBlt',	'GarageFinish',	'GarageCars',	'GarageArea',	'GarageQual',	'GarageCond',	'PavedDrive',	'WoodDeckSF',	'OpenPorchSF',	'EnclosedPorch',	'3SsnPorch',	'ScreenPorch',	'PoolArea',	'MiscVal'], inplace=True)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
df.shape
# Out:
# (1451, 28)

# %% [markdown]
# Now Let's perform all the pandas operation on the dataset. the pandas operation that are to be performed here are:
# * creating different data frames for visualization purpose.
# * Gropuby, multi indexing, merging

# %% [markdown]
# Here what we are doing is that we are creating different data frames and also trying to get some insite from the data.

# %%
# let's create a data frame.

df_10 = df[['MSSubClass','MSZoning','LotArea','Street','LotShape','Utilities','Neighborhood','Condition1','BldgType','OverallCond','SaleCondition','SalePrice']]

# %%
df_10.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond SaleCondition  SalePrice
# 0       Norm     1Fam            5        Normal     208500
# 1      Feedr     1Fam            8        Normal     181500
# 2       Norm     1Fam            5        Normal     223500
# 3       Norm     1Fam            5       Abnorml     140000
# 4       Norm     1Fam            5        Normal     250000

# %%
type(df_10)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Question that can be solved using the above dataframe.

# %% [markdown]
# 1. In building class what is the height count.

# %%
sns.lineplot(df_10['MSSubClass'], df_10['SalePrice'])
# Out:
# c:\Users\mksmu\miniconda3\envs\db\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='MSSubClass', ylabel='SalePrice'>

# %% [markdown]
# From the above we can see that how the cost varies based on sub classes.

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
df['MSZoning'].value_counts()
# Out:
# RL         1145
# RM          218
# FV           62
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
# lets construct a bar plot and see the following:
fig = px.bar(df_10[:20], x = 'MSZoning', y='SalePrice')
fig.update_traces(cliponaxis=False)
fig.show()

# %%
sns.barplot(df['MSZoning'], df['SalePrice'])
# Out:
# c:\Users\mksmu\miniconda3\envs\db\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='MSZoning', ylabel='SalePrice'>

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
px.scatter(df,x = 'MSZoning',y='OverallCond',color='Street', size='OverallCond')

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
plt.bar(df['Street'],df['YearBuilt'] )
# Out:
# <BarContainer object of 1451 artists>

# %%
px.scatter(df,x = 'Utilities',y='OverallCond',color='Neighborhood', size='OverallCond')

# %%
px.scatter(df, y='YearBuilt',x='OverallCond' )

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
px.scatter(df,x = 'RoofStyle',y='OverallCond',color='Neighborhood', size='SalePrice')

# %%
px.pie(df, values='SalePrice', names='Foundation')

# %%
px.bar(df[:50],x='YearBuilt', y='TotalBsmtSF',color='Heating' )

# %%
sns.barplot(df['Exterior2nd'][:20],df['TotalBsmtSF'][:20])
# Out:
# c:\Users\mksmu\miniconda3\envs\db\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Exterior2nd', ylabel='TotalBsmtSF'>

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
sns.scatterplot(df['YearBuilt'][:20], df['SalePrice'][:20])
# Out:
# c:\Users\mksmu\miniconda3\envs\db\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='YearBuilt', ylabel='SalePrice'>

# %%
px.pie(df, values='MoSold', names='Neighborhood')

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
px.scatter(df,x='YrSold', y='SalePrice',color='SaleType')

# %%
px.bar(df,x='YrSold', y='SalePrice',color='SaleCondition')

# %%
px.pie(df, values='SalePrice', names='SaleCondition')

# %%
sns.barplot(data=df,x='Foundation', y='TotalBsmtSF')
# Out:
# <AxesSubplot:xlabel='Foundation', ylabel='TotalBsmtSF'>

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotArea Street LotShape Utilities Neighborhood  \
# 0          60       RL     8450   Pave      Reg    AllPub      CollgCr
# 1          20       RL     9600   Pave      Reg    AllPub      Veenker
# 2          60       RL    11250   Pave      IR1    AllPub      CollgCr
# 3          70       RL     9550   Pave      IR1    AllPub      Crawfor
# 4          60       RL    14260   Pave      IR1    AllPub      NoRidge
#
#   Condition1 BldgType  OverallCond  YearBuilt RoofStyle Exterior2nd  \
# 0       Norm     1Fam            5       2003     Gable     VinylSd
# 1      Feedr     1Fam            8       1976     Gable     MetalSd
# 2       Norm     1Fam            5       2001     Gable     VinylSd
# 3       Norm     1Fam            5       1915     Gable     Wd Shng
# 4       Norm     1Fam            5       2000     Gable     VinylSd
#
#   Foundation  TotalBsmtSF Heating CentralAir Electrical  1stFlrSF  \
# ...

# %%
# Let's see for the good condition for which my house price can be considered.

# %%
new_df = df[['Street', 'Neighborhood','OverallCond','YearBuilt','GarageType','YrSold','SaleType','SaleCondition','SalePrice']]
new_df.head()
# Out:
#   Street Neighborhood  OverallCond  YearBuilt GarageType  YrSold SaleType  \
# 0   Pave      CollgCr            5       2003     Attchd    2008       WD
# 1   Pave      Veenker            8       1976     Attchd    2007       WD
# 2   Pave      CollgCr            5       2001     Attchd    2008       WD
# 3   Pave      Crawfor            5       1915     Detchd    2006       WD
# 4   Pave      NoRidge            5       2000     Attchd    2008       WD
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# 1        Normal     181500
# 2        Normal     223500
# 3       Abnorml     140000
# 4        Normal     250000

# %%
px.bar(new_df,x='Neighborhood', y='OverallCond',color='Street')

# %%
fig = px.scatter(new_df[:50], x="YearBuilt", y="YrSold", color="SaleCondition",
                 size='SalePrice', hover_data=['OverallCond'])
fig.show()

# %%
new_df['SaleType'].value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="52093a50-256f-4825-a78e-80512ac12185" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
fig = px.scatter(new_df[:50], x="YearBuilt", y="YrSold", color="SaleType",
                 size='SalePrice', hover_data=['OverallCond'])
fig.show()

# %%
px.bar(new_df,x='SaleCondition',y='SalePrice')

# %%
new_df['YearBuilt'].value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="d327cfd0-2baa-4fba-9c7a-4c8f34f841b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
new_df['YrSold'].value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="272a07f7-953f-4b95-8484-8a240f24e985" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
new_df.head()
# Out:
#   Street Neighborhood  OverallCond  YearBuilt GarageType  YrSold SaleType  \
# 0   Pave      CollgCr            5       2003     Attchd    2008       WD
# 1   Pave      Veenker            8       1976     Attchd    2007       WD
# 2   Pave      CollgCr            5       2001     Attchd    2008       WD
# 3   Pave      Crawfor            5       1915     Detchd    2006       WD
# 4   Pave      NoRidge            5       2000     Attchd    2008       WD
#
#   SaleCondition  SalePrice
# 0        Normal     208500
# 1        Normal     181500
# 2        Normal     223500
# 3       Abnorml     140000
# 4        Normal     250000

# %%
new_df['SaleType'].value_counts().iplot(kind='bar')
# Out:
# <div>                            <div id="106c1d09-cab6-4dc8-9618-992cc7e4203a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# From all the above we can consider that most of the people buy the house that are newly build say after 2000 and the cost of he house is based on the following condition such as:
# * Street
# * Neighborhood
# * OverallCond
# * YearBuilt
# * GarageType
# * YrSold
# * SaleType
# * SaleCondition
#
# If all the above are in good and satisfying condition then we can say that the cost of house will be high as compared to others.

# %% [markdown]
# # Thank you!
